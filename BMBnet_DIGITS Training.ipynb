# %% [markdown]
# # Loading the DIGITS Dataset

# %% [markdown]
# Don't forget to change runtime type to select a GPU if you are running this notebook in Google Colab.

# %%
import tensorflow as tf
import numpy as np
from keras.datasets import mnist
import pandas as pd
from sklearn.model_selection import train_test_split

seed = 10
np.random.seed(seed)

print("TensorFlow version:", tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

data = pd.read_csv('digits.csv')
X = data.iloc[:, 1:]  
y = data.iloc[:, 0]   

train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.2, stratify=y, random_state=seed)
train_X = np.array(train_X).reshape(train_X.shape[0], 28, 28)
test_X = np.array(test_X).reshape(test_X.shape[0], 28, 28)
# Out:
# TensorFlow version: 2.10.1
# Num GPUs Available:  1

# %% [markdown]
# # Exploratory Data Analysis

# %%
print(f'Train+Validation data shape: {train_X.shape}')
print(f'Test data shape: {test_X.shape}')
# Out:
# Train+Validation data shape: (7315, 28, 28)
# Test data shape: (1829, 28, 28)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(train_X[5*i], cmap = 'gray')
    plt.axis('off')
plt.suptitle('DIGITS Dataset Samples', y=0.94);

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
x, y = np.unique(train_y, return_counts=True)
plt.bar(x, y, color = 'deeppink')
plt.xticks(x); plt.title('Train+Validation Set Label Distribution');

plt.subplot(1, 2, 2)
x, y = np.unique(test_y, return_counts=True)
plt.bar(x, y, color = 'lawngreen')
plt.xticks(x); plt.title('Test Set Label Distribution');

# %%
# %%time
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

colors = plt.colormaps.get_cmap("tab10")

scaler = StandardScaler()
flat = train_X.reshape(-1, 28*28)
scaled_train = scaler.fit_transform(flat)

pca = PCA(n_components=2)
r_PCA = pca.fit_transform(scaled_train)
tsne = TSNE(n_components=2, random_state=seed)
r_TSNE = tsne.fit_transform(scaled_train[:1000])

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
for digit in np.unique(train_y):
    idx = train_y == digit
    plt.scatter(r_PCA[idx, 0], r_PCA[idx, 1], color=colors(digit/10), label=digit, alpha=0.6, edgecolors='w', linewidth=0.5)

plt.title('PCA of Train+Validation')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(loc='upper center', ncol=len(np.unique(train_y)), fontsize=6)
plt.grid(True)

plt.subplot(1, 2, 2)
for digit in np.unique(train_y[:1000]):
    indices = train_y[:1000] == digit
    plt.scatter(r_TSNE[indices, 0], r_TSNE[indices, 1], color=colors(digit/10), label=digit, alpha=0.6, edgecolors='w', linewidth=0.5)

plt.title('t-SNE of the first 1000 samples from Train+Validation')
plt.xlabel('t-SNE Feature 1')
plt.ylabel('t-SNE Feature 2')
plt.legend(loc='upper center', ncol=len(np.unique(train_y)), fontsize=6)
plt.grid(True)
# Out:
# CPU times: total: 15 s
# Wall time: 2.53 s

# %% [markdown]
# We observe that t-SNE provides better clusters with the MNIST dataset compared to PCA. It is also obvious that the problem is not linearly seperable. Hence, a CNN will be trained.

# %% [markdown]
# # Preprocessing the DIGITS Dataset

# %% [markdown]
# We need to convert the dataset into range $[0, 1]$.

# %%
train_X = (train_X/255).astype('float32')
test_X = (test_X/255).astype('float32')
train_X, val_X, train_y, val_y = train_test_split(train_X, train_y, test_size=0.1, random_state=seed, stratify=train_y)

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
x, y = np.unique(train_y, return_counts=True)
plt.bar(x, y, color = 'deeppink')
plt.xticks(x); plt.title('Train Set Label Distribution');

plt.subplot(1, 2, 2)
x, y = np.unique(val_y, return_counts=True)
plt.bar(x, y, color = 'lawngreen')
plt.xticks(x); plt.title('Validation Set Label Distribution');
plt.suptitle('The distribution should look very similar!', fontsize=15);

# %% [markdown]
# We need to match the specified format in ```TensorFlow``` documentation for CNNs. ```[batch_size, height, width, channels]```

# %%
train_X = tf.expand_dims(train_X, axis=-1)
val_X = tf.expand_dims(val_X, axis=-1)
test_X = tf.expand_dims(test_X, axis=-1)

print(f'Train data shape: {train_X.shape}')
print(f'Validation data shape: {val_X.shape}')
print(f'Test data shape: {test_X.shape}')

input_shape = train_X.shape[1:]
# Out:
# Train data shape: (6583, 28, 28, 1)
# Validation data shape: (732, 28, 28, 1)
# Test data shape: (1829, 28, 28, 1)

# %% [markdown]
# We also need to do one-hot encoding of the labels. ```tf.one_hot()``` expects zero based categories so we do a shift first.

# %%
train_y = tf.one_hot(train_y-1, depth = 9)
val_y = tf.one_hot(val_y-1, depth = 9)
test_y = tf.one_hot(test_y-1, depth = 9)

# %% [markdown]
# # Building and Training BMBnet

# %% [markdown]
# Inspired by the [VGG-16 architecture](https://arxiv.org/abs/1409.1556).

# %%
from tensorflow.keras import layers, models

tf.random.set_seed(seed)

BMBnet = models.Sequential(name='BMBnet')
BMBnet.add(layers.Conv2D(8, (3, 3), activation='relu', padding='same', input_shape=input_shape, name='Conv1'))
BMBnet.add(layers.Conv2D(8, (3, 3), activation='relu', padding='same', name='Conv2'))
BMBnet.add(layers.MaxPooling2D((2, 2), strides=2, padding='same', name='MaxPool1'))
BMBnet.add(layers.Conv2D(16, (3, 3), activation='relu', padding='same', name='Conv3'))
BMBnet.add(layers.Conv2D(16, (3, 3), activation='relu', padding='same', name='Conv4'))
BMBnet.add(layers.Conv2D(16, (3, 3), activation='relu', padding='same', name='Conv5'))
BMBnet.add(layers.MaxPooling2D((2, 2), strides = 2, padding = 'same', name='MaxPool2'))
BMBnet.add(layers.Flatten(name='Flatten'))
BMBnet.add(layers.Dense(512, activation = 'relu', name='Dense1'))
BMBnet.add(layers.Dropout(0.5, name='Dropout1'))
BMBnet.add(layers.Dense(512, activation = 'relu', name='Dense2'))
BMBnet.add(layers.Dropout(0.5, name='Dropout2'))
BMBnet.add(layers.Dense(9, activation = 'softmax', name='Dense3'))

BMBnet.summary()
# Out:
# Model: "BMBnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1 (Conv2D)              (None, 28, 28, 8)         80
#
#  Conv2 (Conv2D)              (None, 28, 28, 8)         584
#
#  MaxPool1 (MaxPooling2D)     (None, 14, 14, 8)         0
#
#  Conv3 (Conv2D)              (None, 14, 14, 16)        1168
#
#  Conv4 (Conv2D)              (None, 14, 14, 16)        2320
#
#  Conv5 (Conv2D)              (None, 14, 14, 16)        2320
#
#  MaxPool2 (MaxPooling2D)     (None, 7, 7, 16)          0
#
#  Flatten (Flatten)           (None, 784)               0
#
#  Dense1 (Dense)              (None, 512)               401920
#
#  Dropout1 (Dropout)          (None, 512)               0
#
#  Dense2 (Dense)              (None, 512)               262656
#
#  Dropout2 (Dropout)          (None, 512)               0
#
#  Dense3 (Dense)              (None, 9)                 4617
#
# =================================================================
# Total params: 675,665
# Trainable params: 675,665
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Below is the graphical representation of BMBnet

# %%
tf.keras.utils.plot_model(BMBnet, show_shapes=True)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Defining early stopping criteria.
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    mode='max',
    baseline=None,
    restore_best_weights=True,
)
# Defining metrics to monitor.
metrics=['accuracy', 'AUC', 'Recall', 'Precision']

BMBnet.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=metrics)

epochs = 300
batch_size = 32

data_gen = ImageDataGenerator(
    rotation_range=5,        # Random rotations between -20 to 20 degrees
    width_shift_range=0.1,    # Random horizontal shifts up to 10% of the total width
    height_shift_range=0.1,   # Random vertical shifts up to 10% of the total height
    shear_range=0.1,          # Shear angle in counter-clockwise direction as radians
    zoom_range=0.1,           # Random zoom
    horizontal_flip=False,    # Randomly flip inputs horizontally
    fill_mode='nearest'       # Fill in missing pixels with the nearest filled value
)

train_generator = data_gen.flow(train_X, train_y, batch_size=batch_size)

history = BMBnet.fit(
    train_generator,
    epochs=epochs,
    steps_per_epoch=len(train_X) // batch_size,
    validation_data=(val_X, val_y),
    callbacks=[callback]
)
# Out:
# Epoch 1/300
# 205/205 [==============================] - 7s 14ms/step - loss: 0.7876 - accuracy: 0.7179 - auc: 0.9590 - recall: 0.6286 - precision: 0.8976 - val_loss: 0.0444 - val_accuracy: 0.9877 - val_auc: 0.9999 - val_recall: 0.9795 - val_precision: 0.9931
# Epoch 2/300
# 205/205 [==============================] - 2s 11ms/step - loss: 0.1843 - accuracy: 0.9454 - auc: 0.9960 - recall: 0.9319 - precision: 0.9567 - val_loss: 0.0326 - val_accuracy: 0.9904 - val_auc: 0.9999 - val_recall: 0.9863 - val_precision: 0.9931
# Epoch 3/300
# 205/205 [==============================] - 2s 11ms/step - loss: 0.1214 - accuracy: 0.9621 - auc: 0.9980 - recall: 0.9533 - precision: 0.9709 - val_loss: 0.0160 - val_accuracy: 0.9986 - val_auc: 1.0000 - val_recall: 0.9945 - val_precision: 0.9986
# Epoch 4/300
# 205/205 [==============================] - 2s 11ms/step - loss: 0.0969 - accuracy: 0.9698 - auc: 0.9988 - recall: 0.9635 - precision: 0.9775 - val_loss: 0.0158 - val_accuracy: 0.9945 - val_auc: 1.0000 - val_recall: 0.9932 - val_precision: 0.9973
# Epoch 5/300
# 205/205 [==============================] - 2s 10ms/step - loss: 0.0794 - accuracy: 0.9740 - auc: 0.9990 - recall: 0.9690 - precision: 0.9805 - val_loss: 0.0132 - val_accuracy: 0.9932 - val_auc: 1.0000 - val_recall: 0.9932 - val_precision: 0.9945
# Epoch 6/300
# 205/205 [==============================] - 2s 10ms/step - loss: 0.0735 - accuracy: 0.9782 - auc: 0.9990 - recall: 0.9737 - precision: 0.9821 - val_loss: 0.0077 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_recall: 0.9973 - val_precision: 1.0000
# Epoch 7/300
# 205/205 [==============================] - 2s 11ms/step - loss: 0.0667 - accuracy: 0.9794 - auc: 0.9992 - recall: 0.9754 - precision: 0.9832 - val_loss: 0.0118 - val_accuracy: 0.9945 - val_auc: 1.0000 - val_recall: 0.9932 - val_precision: 0.9959
# Epoch 8/300
# 205/205 [==============================] - 2s 11ms/step - loss: 0.0615 - accuracy: 0.9821 - auc: 0.9991 - recall: 0.9780 - precision: 0.9854 - val_loss: 0.0106 - val_accuracy: 0.9959 - val_auc: 1.0000 - val_recall: 0.9945 - val_precision: 0.9973
# Epoch 9/300
# 205/205 [==============================] - 2s 11ms/step - loss: 0.0525 - accuracy: 0.9840 - auc: 0.9994 - recall: 0.9811 - precision: 0.9874 - val_loss: 0.0084 - val_accuracy: 0.9973 - val_auc: 1.0000 - val_recall: 0.9945 - val_precision: 0.9973
# Epoch 10/300
# 205/205 [==============================] - 2s 11ms/step - loss: 0.0559 - accuracy: 0.9818 - auc: 0.9992 - recall: 0.9785 - precision: 0.9849 - val_loss: 0.0093 - val_accuracy: 0.9986 - val_auc: 1.0000 - val_recall: 0.9945 - val_precision: 1.0000
# Epoch 11/300
# 205/205 [==============================] - 2s 11ms/step - loss: 0.0585 - accuracy: 0.9828 - auc: 0.9991 - recall: 0.9808 - precision: 0.9850 - val_loss: 0.0123 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_recall: 0.9904 - val_precision: 1.0000
# Epoch 12/300
# 205/205 [==============================] - 2s 11ms/step - loss: 0.0415 - accuracy: 0.9866 - auc: 0.9994 - recall: 0.9844 - precision: 0.9894 - val_loss: 0.0109 - val_accuracy: 0.9973 - val_auc: 1.0000 - val_recall: 0.9959 - val_precision: 0.9973
# Epoch 13/300
# 205/205 [==============================] - 2s 11ms/step - loss: 0.0468 - accuracy: 0.9863 - auc: 0.9994 - recall: 0.9840 - precision: 0.9890 - val_loss: 0.0167 - val_accuracy: 0.9945 - val_auc: 1.0000 - val_recall: 0.9932 - val_precision: 0.9945
# Epoch 14/300
# 205/205 [==============================] - 2s 12ms/step - loss: 0.0453 - accuracy: 0.9841 - auc: 0.9994 - recall: 0.9823 - precision: 0.9882 - val_loss: 0.0144 - val_accuracy: 0.9945 - val_auc: 1.0000 - val_recall: 0.9945 - val_precision: 0.9945
# Epoch 15/300
# 205/205 [==============================] - 2s 11ms/step - loss: 0.0485 - accuracy: 0.9841 - auc: 0.9993 - recall: 0.9821 - precision: 0.9867 - val_loss: 0.0101 - val_accuracy: 0.9973 - val_auc: 1.0000 - val_recall: 0.9973 - val_precision: 0.9986
# Epoch 16/300
# 205/205 [==============================] - 2s 11ms/step - loss: 0.0406 - accuracy: 0.9872 - auc: 0.9995 - recall: 0.9855 - precision: 0.9896 - val_loss: 0.0079 - val_accuracy: 0.9973 - val_auc: 1.0000 - val_recall: 0.9959 - val_precision: 0.9973

# %%
best_epoch = np.argmax(history.history['val_accuracy'])
val_accuracy = history.history['val_accuracy'][best_epoch]
train_accuracy = history.history['accuracy'][best_epoch]

plt.figure(figsize=(20, 5))
plt.plot(history.history['accuracy'], label='Train', lw=3)
plt.plot(history.history['val_accuracy'], label = 'Validation', lw=3)
plt.plot(best_epoch, val_accuracy, marker='o', label='Best Epoch', markersize=10)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([min(np.min(history.history['val_accuracy']), np.min(history.history['accuracy'])), 1])
plt.xlim([0, len(history.history['accuracy'])])
plt.xticks(np.arange(0, len(history.history['accuracy'])))
plt.legend(loc='lower right')
plt.grid()
plt.title('Epoch History of BMBnet Training', fontsize=15, loc='center');

# %% [markdown]
# # Performance of BMBnet on DIGITS Dataset

# %%
import pandas as pd
from absl import logging as absl_logging

test_loss, test_accuracy, test_auc, test_recall, test_precision = BMBnet.evaluate(test_X,  test_y, verbose=0)

results = dict()
for metric in metrics:
    results[metric] = [history.history[f'{metric.lower()}'][best_epoch], history.history[f'val_{metric.lower()}'][best_epoch]]
test_col = [test_accuracy, test_auc, test_recall, test_precision]

result_df = pd.DataFrame.from_dict(results, orient='index', columns=['Train', 'Validation'])
result_df['Test'] = test_col
result_df.index = ['Accuracy'] + metrics[1::]

display(result_df)
absl_logging.set_verbosity(absl_logging.ERROR)
tf.get_logger().setLevel('ERROR')
#BMBnet.save('BMBnet_DIGITS', overwrite=True)
# Out:
#               Train  Validation      Test
# Accuracy   0.978171    1.000000  0.996173
# AUC        0.999005    1.000000  0.999994
# Recall     0.973744    0.997268  0.995079
# Precision  0.982140    1.000000  0.998354

# %% [markdown]
# # Visualising Results on Test Set

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

predictions = BMBnet.predict(test_X, verbose=None)
predicted_classes = np.argmax(predictions, axis=1)+1 # Class offset +1

true_classes = np.argmax(test_y, axis=1)+1 # Class offset +1
conf_matrix = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=np.arange(1, 9), yticklabels=np.arange(1, 9))
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix');
